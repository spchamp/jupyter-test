# %%
# %matplotlib inline
# %pip install -q seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

## sample data from Utts Chapter 7, p. 138
ages = [36, 52, 60, 60, 62, 65, 65, 65, 70, 72, 74, 75, 75, 76, 76, 78, 79, 79, 80, 80, 82,  83, 84, 85, 88, 90, 90, 92, 95, 98, 99]

plt.style.use('Solarize_Light2')
sns.set(rc={'figure.figsize':(8.7,1.80)})

wplot = sns.boxplot(x = ages)
wplot.set(title = "Example", xlabel="Age")
# Out:
# [Text(0.5, 1.0, 'Example'), Text(0.5, 0, 'Age')]
